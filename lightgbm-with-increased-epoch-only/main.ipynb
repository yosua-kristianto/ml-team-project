# %% [markdown]
# # Default Credit Classifier
#
# Please read ReadMe.md file to learn more about the pre-requisites to run this Jupyter Notebook file.

# %% [markdown]
# ## Importing packages

# %%
import lightgbm;
import pandas
import matplotlib.pyplot as plt;
from sklearn.model_selection import train_test_split;
from sklearn.metrics import accuracy_score, log_loss, roc_auc_score;

# %% [markdown]
# ## Data Pre-Processing
#
# To coup up, data pre-processing had steps below:
#
# 1. Taking pre-cleaned csv file
# The pre-cleaned csv here, means that the header that contains X1 to Y row is cleaned. And change the label column header as "LABEL"
#
# 2. Data cleaning
# Some exist data is stored and not having value of the one that documented. To prevent any classification errors, we removing it.
#
# 3. Perform One-Hot Encoding for the ordinal values

# %%
# Loading data from pre-cleaned csv file
dataframe = pandas.read_csv("credit_card_clients.csv");

# Some education data contains 0, 5, and 6. I eliminating 'em.

invalid_education_data = [];
for idx, e in enumerate(dataframe['EDUCATION']):
    if(e > 4 or e < 1):
        invalid_education_data.append(idx);

# Some marriage data contains 0. I eliminating 'em.

invalid_marriage_data = [];
for idx, e in enumerate(dataframe['MARRIAGE']):
    if(e == 0):
        invalid_marriage_data.append(idx);

final_invalid_data_index = [];
for e in [invalid_marriage_data, invalid_education_data]:
    for f in e:
        
        # Check the index. If it throw exception, append the number. 
        try:
            final_invalid_data_index.index(f);
            continue;
        except:
            final_invalid_data_index.append(f);

dataframe = dataframe.drop(final_invalid_data_index);

# Make one hot encoding for Sex, Educuation, and Marriage since the data is an ordinal data
hot_encoded_sex = pandas.get_dummies(dataframe['SEX'], prefix = "sex");
hot_encoded_education = pandas.get_dummies(dataframe['EDUCATION'], prefix = "education");
hot_encoded_marital_status = pandas.get_dummies(dataframe['MARRIAGE'], prefix = "marital_status");

# Merge the hot_encoded with the main dataframe
for i in [hot_encoded_sex, hot_encoded_education,hot_encoded_marital_status]:
    dataframe = pandas.concat([dataframe, i], axis = 1);



print("Data after cleaning: ", dataframe.shape);
print(dataframe.columns.tolist());
# Out:
# Data after cleaning:  (29601, 34)
# ['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0', 'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2', 'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1', 'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6', 'LABEL', 'sex_1', 'sex_2', 'education_1', 'education_2', 'education_3', 'education_4', 'marital_status_1', 'marital_status_2', 'marital_status_3']

# %% [markdown]
# ## Split train-test data
# In this part, we split the data by 9:1 percentile. Also defining which one is label and features.

# %%
# Define label data
label = dataframe['LABEL'];

# Drop ID, SEX, EDUCATION, MARRIAGE, and LABEL from dataframe for features
features = dataframe.drop(columns=["ID", "SEX", "EDUCATION", "MARRIAGE", "LABEL"]);

# Split the data into training and testing sets
feature_train, feature_test, label_train, label_test = train_test_split(features, label, test_size=0.1, random_state=0);

train_data = lightgbm.Dataset(feature_train, label = label_train);
test_data = lightgbm.Dataset(feature_test, label = label_test, reference = train_data);

# %% [markdown]
# # Model fitting meta data
# Here lies the meta data for training the model

# %%
# Set up the configuration for LightGBM
config = {
    "objective": "binary",
    "metric": {"binary_logloss"},
    "is_training_metric": True,
    "boosting_type": "gbdt",
    "num_leaves": 31,
    "learning_rate": 1e-3,
    "feature_fraction": 0.9,
    "verbosity": 1,
    "device_type": "cpu",
    "early_stopping_round": 100,
};

epochs = 100000;
evaluation_result = {};

# %% [markdown]
# # Fitting model

# %%
# Train the LightGBM model
model = lightgbm.train(params=config, train_set=train_data, num_boost_round=epochs, valid_sets=[test_data], callbacks=[lightgbm.record_evaluation(evaluation_result), lightgbm.log_evaluation()]);
# Out:
# [LightGBM] [Info] Number of positive: 6002, number of negative: 20638
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002579 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3272
# [LightGBM] [Info] Number of data points in the train set: 26640, number of used features: 29
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.225300 -> initscore=-1.235041
# [LightGBM] [Info] Start training from score -1.235041
# [1]	valid_0's binary_logloss: 0.50659
# Training until validation scores don't improve for 100 rounds
# [2]	valid_0's binary_logloss: 0.506389
# [3]	valid_0's binary_logloss: 0.506191
# [4]	valid_0's binary_logloss: 0.505994
# [5]	valid_0's binary_logloss: 0.505793
# [6]	valid_0's binary_logloss: 0.505593
# [7]	valid_0's binary_logloss: 0.505393
# [8]	valid_0's binary_logloss: 0.505196
# [9]	valid_0's binary_logloss: 0.505006
# [10]	valid_0's binary_logloss: 0.504809
# [11]	valid_0's binary_logloss: 0.504612
# [12]	valid_0's binary_logloss: 0.504476
# [13]	valid_0's binary_logloss: 0.504338
# [14]	valid_0's binary_logloss: 0.5042
# [15]	valid_0's binary_logloss: 0.504005
# [16]	valid_0's binary_logloss: 0.503808
# [17]	valid_0's binary_logloss: 0.503614
# [18]	valid_0's binary_logloss: 0.503425
# [19]	valid_0's binary_logloss: 0.503233
# [20]	valid_0's binary_logloss: 0.503044
# [21]	valid_0's binary_logloss: 0.502856
# [22]	valid_0's binary_logloss: 0.502662
# [23]	valid_0's binary_logloss: 0.502471
# [24]	valid_0's binary_logloss: 0.502282
# [25]	valid_0's binary_logloss: 0.502099
# [26]	valid_0's binary_logloss: 0.501912
# [27]	valid_0's binary_logloss: 0.501722
# [28]	valid_0's binary_logloss: 0.501535
# [29]	valid_0's binary_logloss: 0.501344
# [30]	valid_0's binary_logloss: 0.501157
# [31]	valid_0's binary_logloss: 0.500976
# [32]	valid_0's binary_logloss: 0.500788
# [33]	valid_0's binary_logloss: 0.500606
# [34]	valid_0's binary_logloss: 0.50042
# [35]	valid_0's binary_logloss: 0.500238
# [36]	valid_0's binary_logloss: 0.500053
# [37]	valid_0's binary_logloss: 0.499874
# [38]	valid_0's binary_logloss: 0.499692
# [39]	valid_0's binary_logloss: 0.499513
# [40]	valid_0's binary_logloss: 0.499383
# [41]	valid_0's binary_logloss: 0.499203
# [42]	valid_0's binary_logloss: 0.499025
# [43]	valid_0's binary_logloss: 0.498896
# [44]	valid_0's binary_logloss: 0.498719
# [45]	valid_0's binary_logloss: 0.498537
# [46]	valid_0's binary_logloss: 0.498359
# [47]	valid_0's binary_logloss: 0.498182
# [48]	valid_0's binary_logloss: 0.498055
# [49]	valid_0's binary_logloss: 0.49788
# [50]	valid_0's binary_logloss: 0.497705
# [51]	valid_0's binary_logloss: 0.497528
# [52]	valid_0's binary_logloss: 0.49735
# [53]	valid_0's binary_logloss: 0.497174
# [54]	valid_0's binary_logloss: 0.496998
# [55]	valid_0's binary_logloss: 0.496826
# [56]	valid_0's binary_logloss: 0.496659
# [57]	valid_0's binary_logloss: 0.496484
# [58]	valid_0's binary_logloss: 0.496314
# [59]	valid_0's binary_logloss: 0.49614
# [60]	valid_0's binary_logloss: 0.495967
# [61]	valid_0's binary_logloss: 0.495793
# [62]	valid_0's binary_logloss: 0.495621
# [63]	valid_0's binary_logloss: 0.49545
# [64]	valid_0's binary_logloss: 0.495277
# [65]	valid_0's binary_logloss: 0.495107
# [66]	valid_0's binary_logloss: 0.494937
# [67]	valid_0's binary_logloss: 0.494769
# [68]	valid_0's binary_logloss: 0.494606
# [69]	valid_0's binary_logloss: 0.494438
# [70]	valid_0's binary_logloss: 0.494269
# [71]	valid_0's binary_logloss: 0.494104
# [72]	valid_0's binary_logloss: 0.493933
# [73]	valid_0's binary_logloss: 0.493767
# [74]	valid_0's binary_logloss: 0.4936
# [75]	valid_0's binary_logloss: 0.493434
# [76]	valid_0's binary_logloss: 0.493268
# [77]	valid_0's binary_logloss: 0.493104
# [78]	valid_0's binary_logloss: 0.492989
# [79]	valid_0's binary_logloss: 0.492832
# [80]	valid_0's binary_logloss: 0.492675
# [81]	valid_0's binary_logloss: 0.49251
# [82]	valid_0's binary_logloss: 0.492349
# [83]	valid_0's binary_logloss: 0.492186
# [84]	valid_0's binary_logloss: 0.492078
# [85]	valid_0's binary_logloss: 0.491961
# [86]	valid_0's binary_logloss: 0.4918
# [87]	valid_0's binary_logloss: 0.491641
# [88]	valid_0's binary_logloss: 0.49148
# [89]	valid_0's binary_logloss: 0.491319
# [90]	valid_0's binary_logloss: 0.49116
# [91]	valid_0's binary_logloss: 0.491004
# [92]	valid_0's binary_logloss: 0.490843
# [93]	valid_0's binary_logloss: 0.490728
# [94]	valid_0's binary_logloss: 0.490569
# [95]	valid_0's binary_logloss: 0.490453
# [96]	valid_0's binary_logloss: 0.490291
# [97]	valid_0's binary_logloss: 0.49013
# [98]	valid_0's binary_logloss: 0.489973
# [99]	valid_0's binary_logloss: 0.489823
# [100]	valid_0's binary_logloss: 0.489662
# [101]	valid_0's binary_logloss: 0.489508
# [102]	valid_0's binary_logloss: 0.489353
# [103]	valid_0's binary_logloss: 0.489238
# [104]	valid_0's binary_logloss: 0.489086
# [105]	valid_0's binary_logloss: 0.488936
# [106]	valid_0's binary_logloss: 0.488825
# [107]	valid_0's binary_logloss: 0.488675
# [108]	valid_0's binary_logloss: 0.48852
# [109]	valid_0's binary_logloss: 0.488363
# [110]	valid_0's binary_logloss: 0.488211
# [111]	valid_0's binary_logloss: 0.488059
# [112]	valid_0's binary_logloss: 0.487912
# [113]	valid_0's binary_logloss: 0.48781
# [114]	valid_0's binary_logloss: 0.487655
# [115]	valid_0's binary_logloss: 0.487506
# [116]	valid_0's binary_logloss: 0.487355
# [117]	valid_0's binary_logloss: 0.487202
# [118]	valid_0's binary_logloss: 0.487053
# [119]	valid_0's binary_logloss: 0.486944
# [120]	valid_0's binary_logloss: 0.486795
# [121]	valid_0's binary_logloss: 0.486642
# [122]	valid_0's binary_logloss: 0.486497
# [123]	valid_0's binary_logloss: 0.486349
# [124]	valid_0's binary_logloss: 0.4862
# [125]	valid_0's binary_logloss: 0.486056
# [126]	valid_0's binary_logloss: 0.485909
# [127]	valid_0's binary_logloss: 0.485763
# [128]	valid_0's binary_logloss: 0.48562
# [129]	valid_0's binary_logloss: 0.485475
# [130]	valid_0's binary_logloss: 0.485333
# [131]	valid_0's binary_logloss: 0.485192
# [132]	valid_0's binary_logloss: 0.48505
# [133]	valid_0's binary_logloss: 0.484953
# [134]	valid_0's binary_logloss: 0.484812
# [135]	valid_0's binary_logloss: 0.484668
# [136]	valid_0's binary_logloss: 0.484572
# [137]	valid_0's binary_logloss: 0.484433
# [138]	valid_0's binary_logloss: 0.484289
# [139]	valid_0's binary_logloss: 0.484151
# [140]	valid_0's binary_logloss: 0.484012
# [141]	valid_0's binary_logloss: 0.483908
# [142]	valid_0's binary_logloss: 0.483767
# [143]	valid_0's binary_logloss: 0.483629
# [144]	valid_0's binary_logloss: 0.483487
# [145]	valid_0's binary_logloss: 0.483347
# [146]	valid_0's binary_logloss: 0.483244
# [147]	valid_0's binary_logloss: 0.483108
# [148]	valid_0's binary_logloss: 0.482975
# [149]	valid_0's binary_logloss: 0.482837
# [150]	valid_0's binary_logloss: 0.482702
# [151]	valid_0's binary_logloss: 0.482563
# [152]	valid_0's binary_logloss: 0.482426
# [153]	valid_0's binary_logloss: 0.482288
# [154]	valid_0's binary_logloss: 0.482149
# [155]	valid_0's binary_logloss: 0.482015
# [156]	valid_0's binary_logloss: 0.481878
# [157]	valid_0's binary_logloss: 0.481742
# [158]	valid_0's binary_logloss: 0.481609
# [159]	valid_0's binary_logloss: 0.481474
# [160]	valid_0's binary_logloss: 0.48134
# [161]	valid_0's binary_logloss: 0.481204
# [162]	valid_0's binary_logloss: 0.481072
# [163]	valid_0's binary_logloss: 0.480935
# [164]	valid_0's binary_logloss: 0.4808
# [165]	valid_0's binary_logloss: 0.480665
# [166]	valid_0's binary_logloss: 0.48053
# [167]	valid_0's binary_logloss: 0.480432
# [168]	valid_0's binary_logloss: 0.480301
# [169]	valid_0's binary_logloss: 0.480173
# [170]	valid_0's binary_logloss: 0.480042
# [171]	valid_0's binary_logloss: 0.479915
# [172]	valid_0's binary_logloss: 0.479783
# [173]	valid_0's binary_logloss: 0.479655
# [174]	valid_0's binary_logloss: 0.479527
# [175]	valid_0's binary_logloss: 0.479396
# [176]	valid_0's binary_logloss: 0.479264
# [177]	valid_0's binary_logloss: 0.479137
# [178]	valid_0's binary_logloss: 0.479005
# [179]	valid_0's binary_logloss: 0.478875
# [180]	valid_0's binary_logloss: 0.478783
# [181]	valid_0's binary_logloss: 0.478652
# [182]	valid_0's binary_logloss: 0.478558
# [183]	valid_0's binary_logloss: 0.478429
# [184]	valid_0's binary_logloss: 0.478302
# [185]	valid_0's binary_logloss: 0.478175
# [186]	valid_0's binary_logloss: 0.478046
# [187]	valid_0's binary_logloss: 0.477918
# [188]	valid_0's binary_logloss: 0.477792
# [189]	valid_0's binary_logloss: 0.477669
# [190]	valid_0's binary_logloss: 0.477542
# [191]	valid_0's binary_logloss: 0.477455
# [192]	valid_0's binary_logloss: 0.47733
# [193]	valid_0's binary_logloss: 0.477206
# [194]	valid_0's binary_logloss: 0.47708
# [195]	valid_0's binary_logloss: 0.476956
# [196]	valid_0's binary_logloss: 0.476833
# [197]	valid_0's binary_logloss: 0.476707
# [198]	valid_0's binary_logloss: 0.476583
# [199]	valid_0's binary_logloss: 0.476462
# [200]	valid_0's binary_logloss: 0.476339
# [201]	valid_0's binary_logloss: 0.47622
# [202]	valid_0's binary_logloss: 0.476099
# [203]	valid_0's binary_logloss: 0.476012
# [204]	valid_0's binary_logloss: 0.475922
# [205]	valid_0's binary_logloss: 0.475799
# [206]	valid_0's binary_logloss: 0.475678
# [207]	valid_0's binary_logloss: 0.475557
# [208]	valid_0's binary_logloss: 0.475438
# [209]	valid_0's binary_logloss: 0.475319
# [210]	valid_0's binary_logloss: 0.475197
# [211]	valid_0's binary_logloss: 0.475078
# [212]	valid_0's binary_logloss: 0.474959
# [213]	valid_0's binary_logloss: 0.474841
# [214]	valid_0's binary_logloss: 0.474724
# [215]	valid_0's binary_logloss: 0.474607
# [216]	valid_0's binary_logloss: 0.474491
# [217]	valid_0's binary_logloss: 0.474376
# [218]	valid_0's binary_logloss: 0.474261
# [219]	valid_0's binary_logloss: 0.474143
# [220]	valid_0's binary_logloss: 0.474057
# [221]	valid_0's binary_logloss: 0.473938
# [222]	valid_0's binary_logloss: 0.473822
# [223]	valid_0's binary_logloss: 0.473703
# [224]	valid_0's binary_logloss: 0.473586
# [225]	valid_0's binary_logloss: 0.473474
# [226]	valid_0's binary_logloss: 0.47336
# [227]	valid_0's binary_logloss: 0.473278
# [228]	valid_0's binary_logloss: 0.473195
# [229]	valid_0's binary_logloss: 0.473083
# [230]	valid_0's binary_logloss: 0.472998
# [231]	valid_0's binary_logloss: 0.472882
# [232]	valid_0's binary_logloss: 0.47277
# [233]	valid_0's binary_logloss: 0.472653
# [234]	valid_0's binary_logloss: 0.47254
# [235]	valid_0's binary_logloss: 0.472426
# [236]	valid_0's binary_logloss: 0.472313
# [237]	valid_0's binary_logloss: 0.4722
# [238]	valid_0's binary_logloss: 0.472089
# [239]	valid_0's binary_logloss: 0.471976
# [240]	valid_0's binary_logloss: 0.471864
# [241]	valid_0's binary_logloss: 0.471756
# [242]	valid_0's binary_logloss: 0.471644
# [243]	valid_0's binary_logloss: 0.471531
# [244]	valid_0's binary_logloss: 0.47142
# [245]	valid_0's binary_logloss: 0.47131
# [246]	valid_0's binary_logloss: 0.471202
# [247]	valid_0's binary_logloss: 0.471092
# [248]	valid_0's binary_logloss: 0.470983
# [249]	valid_0's binary_logloss: 0.470872
# [250]	valid_0's binary_logloss: 0.470763
# [251]	valid_0's binary_logloss: 0.470652
# [252]	valid_0's binary_logloss: 0.470543
# [253]	valid_0's binary_logloss: 0.470432
# [254]	valid_0's binary_logloss: 0.470351
# [255]	valid_0's binary_logloss: 0.470241
# [256]	valid_0's binary_logloss: 0.470162
# [257]	valid_0's binary_logloss: 0.470058
# [258]	valid_0's binary_logloss: 0.469948
# [259]	valid_0's binary_logloss: 0.469841
# [260]	valid_0's binary_logloss: 0.469734
# [261]	valid_0's binary_logloss: 0.469626
# [262]	valid_0's binary_logloss: 0.469517
# [263]	valid_0's binary_logloss: 0.469409
# [264]	valid_0's binary_logloss: 0.469304
# [265]	valid_0's binary_logloss: 0.469193
# [266]	valid_0's binary_logloss: 0.469087
# [267]	valid_0's binary_logloss: 0.468979
# [268]	valid_0's binary_logloss: 0.468874
# [269]	valid_0's binary_logloss: 0.468772
# [270]	valid_0's binary_logloss: 0.468666
# [271]	valid_0's binary_logloss: 0.468556
# [272]	valid_0's binary_logloss: 0.468453
# [273]	valid_0's binary_logloss: 0.46835
# [274]	valid_0's binary_logloss: 0.468272
# [275]	valid_0's binary_logloss: 0.468172
# [276]	valid_0's binary_logloss: 0.468068
# [277]	valid_0's binary_logloss: 0.467964
# [278]	valid_0's binary_logloss: 0.467859
# [279]	valid_0's binary_logloss: 0.467757
# [280]	valid_0's binary_logloss: 0.467654
# [281]	valid_0's binary_logloss: 0.467552
# [282]	valid_0's binary_logloss: 0.467448
# [283]	valid_0's binary_logloss: 0.467347
# [284]	valid_0's binary_logloss: 0.467246
# [285]	valid_0's binary_logloss: 0.467143
# [286]	valid_0's binary_logloss: 0.46704
# [287]	valid_0's binary_logloss: 0.466938
# [288]	valid_0's binary_logloss: 0.466837
# [289]	valid_0's binary_logloss: 0.466733
# [290]	valid_0's binary_logloss: 0.466635
# [291]	valid_0's binary_logloss: 0.466533
# [292]	valid_0's binary_logloss: 0.466432
# [293]	valid_0's binary_logloss: 0.466331
# [294]	valid_0's binary_logloss: 0.466226
# [295]	valid_0's binary_logloss: 0.466129
# [296]	valid_0's binary_logloss: 0.466028
# [297]	valid_0's binary_logloss: 0.465955
# [298]	valid_0's binary_logloss: 0.465855
# [299]	valid_0's binary_logloss: 0.465757
# [300]	valid_0's binary_logloss: 0.465658
# [301]	valid_0's binary_logloss: 0.46556
# [302]	valid_0's binary_logloss: 0.465463
# [303]	valid_0's binary_logloss: 0.465361
# [304]	valid_0's binary_logloss: 0.465264
# [305]	valid_0's binary_logloss: 0.465164
# [306]	valid_0's binary_logloss: 0.465064
# [307]	valid_0's binary_logloss: 0.464964
# [308]	valid_0's binary_logloss: 0.464868
# [309]	valid_0's binary_logloss: 0.464796
# [310]	valid_0's binary_logloss: 0.464696
# [311]	valid_0's binary_logloss: 0.464624
# [312]	valid_0's binary_logloss: 0.46453
# [313]	valid_0's binary_logloss: 0.464434
# [314]	valid_0's binary_logloss: 0.464336
# [315]	valid_0's binary_logloss: 0.464238
# [316]	valid_0's binary_logloss: 0.464145
# [317]	valid_0's binary_logloss: 0.464048
# [318]	valid_0's binary_logloss: 0.46395
# [319]	valid_0's binary_logloss: 0.463857
# [320]	valid_0's binary_logloss: 0.463765
# [321]	valid_0's binary_logloss: 0.463693
# [322]	valid_0's binary_logloss: 0.463595
# [323]	valid_0's binary_logloss: 0.463498
# [324]	valid_0's binary_logloss: 0.4634
# [325]	valid_0's binary_logloss: 0.463305
# [326]	valid_0's binary_logloss: 0.463215
# [327]	valid_0's binary_logloss: 0.463119
# [328]	valid_0's binary_logloss: 0.463025
# [329]	valid_0's binary_logloss: 0.462933
# [330]	valid_0's binary_logloss: 0.462841
# [331]	valid_0's binary_logloss: 0.462747
# [332]	valid_0's binary_logloss: 0.462658
# [333]	valid_0's binary_logloss: 0.462569
# [334]	valid_0's binary_logloss: 0.462476
# [335]	valid_0's binary_logloss: 0.462384
# [336]	valid_0's binary_logloss: 0.462315
# [337]	valid_0's binary_logloss: 0.462226
# [338]	valid_0's binary_logloss: 0.462136
# [339]	valid_0's binary_logloss: 0.462045
# [340]	valid_0's binary_logloss: 0.461956
# [341]	valid_0's binary_logloss: 0.461865
# [342]	valid_0's binary_logloss: 0.461774
# [343]	valid_0's binary_logloss: 0.461683
# [344]	valid_0's binary_logloss: 0.461592
# [345]	valid_0's binary_logloss: 0.461525
# [346]	valid_0's binary_logloss: 0.461435
# [347]	valid_0's binary_logloss: 0.461346
# [348]	valid_0's binary_logloss: 0.461257
# [349]	valid_0's binary_logloss: 0.46117
# [350]	valid_0's binary_logloss: 0.461082
# [351]	valid_0's binary_logloss: 0.460995
# [352]	valid_0's binary_logloss: 0.460906
# [353]	valid_0's binary_logloss: 0.460821
# [354]	valid_0's binary_logloss: 0.460731
# [355]	valid_0's binary_logloss: 0.460643
# [356]	valid_0's binary_logloss: 0.460578
# [357]	valid_0's binary_logloss: 0.460491
# [358]	valid_0's binary_logloss: 0.460405
# [359]	valid_0's binary_logloss: 0.460319
# [360]	valid_0's binary_logloss: 0.460235
# [361]	valid_0's binary_logloss: 0.460147
# [362]	valid_0's binary_logloss: 0.460084
# [363]	valid_0's binary_logloss: 0.459998
# [364]	valid_0's binary_logloss: 0.459912
# [365]	valid_0's binary_logloss: 0.459846
# [366]	valid_0's binary_logloss: 0.45976
# [367]	valid_0's binary_logloss: 0.459675
# [368]	valid_0's binary_logloss: 0.45959
# [369]	valid_0's binary_logloss: 0.459506
# [370]	valid_0's binary_logloss: 0.459423
# [371]	valid_0's binary_logloss: 0.459358
# [372]	valid_0's binary_logloss: 0.459272
# [373]	valid_0's binary_logloss: 0.459189
# [374]	valid_0's binary_logloss: 0.459102
# [375]	valid_0's binary_logloss: 0.459016
# [376]	valid_0's binary_logloss: 0.458951
# [377]	valid_0's binary_logloss: 0.458867
# [378]	valid_0's binary_logloss: 0.458782
# [379]	valid_0's binary_logloss: 0.458698
# [380]	valid_0's binary_logloss: 0.458613
# [381]	valid_0's binary_logloss: 0.458529
# [382]	valid_0's binary_logloss: 0.458447
# [383]	valid_0's binary_logloss: 0.458364
# [384]	valid_0's binary_logloss: 0.4583
# [385]	valid_0's binary_logloss: 0.458216
# [386]	valid_0's binary_logloss: 0.458133
# [387]	valid_0's binary_logloss: 0.45805
# [388]	valid_0's binary_logloss: 0.457969
# [389]	valid_0's binary_logloss: 0.457889
# [390]	valid_0's binary_logloss: 0.457809
# [391]	valid_0's binary_logloss: 0.457723
# [392]	valid_0's binary_logloss: 0.457639
# [393]	valid_0's binary_logloss: 0.457556
# [394]	valid_0's binary_logloss: 0.457474
# [395]	valid_0's binary_logloss: 0.457394
# [396]	valid_0's binary_logloss: 0.457314
# [397]	valid_0's binary_logloss: 0.457232
# [398]	valid_0's binary_logloss: 0.457154
# [399]	valid_0's binary_logloss: 0.457075
# [400]	valid_0's binary_logloss: 0.456995
# [401]	valid_0's binary_logloss: 0.456914
# [402]	valid_0's binary_logloss: 0.456837
# [403]	valid_0's binary_logloss: 0.456757
# [404]	valid_0's binary_logloss: 0.456677
# [405]	valid_0's binary_logloss: 0.456596
# [406]	valid_0's binary_logloss: 0.456516
# [407]	valid_0's binary_logloss: 0.456435
# [408]	valid_0's binary_logloss: 0.456354
# [409]	valid_0's binary_logloss: 0.456276
# [410]	valid_0's binary_logloss: 0.456199
# [411]	valid_0's binary_logloss: 0.456119
# [412]	valid_0's binary_logloss: 0.45604
# [413]	valid_0's binary_logloss: 0.455959
# [414]	valid_0's binary_logloss: 0.455882
# [415]	valid_0's binary_logloss: 0.455802
# [416]	valid_0's binary_logloss: 0.455723
# [417]	valid_0's binary_logloss: 0.455647
# [418]	valid_0's binary_logloss: 0.455565
# [419]	valid_0's binary_logloss: 0.455487
# [420]	valid_0's binary_logloss: 0.455409
# [421]	valid_0's binary_logloss: 0.455332
# [422]	valid_0's binary_logloss: 0.455257
# [423]	valid_0's binary_logloss: 0.455179
# [424]	valid_0's binary_logloss: 0.455102
# [425]	valid_0's binary_logloss: 0.455026
# [426]	valid_0's binary_logloss: 0.454948
# [427]	valid_0's binary_logloss: 0.454893
# [428]	valid_0's binary_logloss: 0.454838
# [429]	valid_0's binary_logloss: 0.454762
# [430]	valid_0's binary_logloss: 0.454687
# [431]	valid_0's binary_logloss: 0.454611
# [432]	valid_0's binary_logloss: 0.454537
# [433]	valid_0's binary_logloss: 0.454459
# [434]	valid_0's binary_logloss: 0.454405
# [435]	valid_0's binary_logloss: 0.454329
# [436]	valid_0's binary_logloss: 0.454251
# [437]	valid_0's binary_logloss: 0.454178
# [438]	valid_0's binary_logloss: 0.454105
# [439]	valid_0's binary_logloss: 0.454029
# [440]	valid_0's binary_logloss: 0.453955
# [441]	valid_0's binary_logloss: 0.4539
# [442]	valid_0's binary_logloss: 0.453827
# [443]	valid_0's binary_logloss: 0.453752
# [444]	valid_0's binary_logloss: 0.45368
# [445]	valid_0's binary_logloss: 0.453605
# [446]	valid_0's binary_logloss: 0.453552
# [447]	valid_0's binary_logloss: 0.453477
# [448]	valid_0's binary_logloss: 0.453403
# [449]	valid_0's binary_logloss: 0.453351
# [450]	valid_0's binary_logloss: 0.45328
# [451]	valid_0's binary_logloss: 0.453206
# [452]	valid_0's binary_logloss: 0.453132
# [453]	valid_0's binary_logloss: 0.453061
# [454]	valid_0's binary_logloss: 0.452987
# [455]	valid_0's binary_logloss: 0.452915
# [456]	valid_0's binary_logloss: 0.452863
# [457]	valid_0's binary_logloss: 0.452791
# [458]	valid_0's binary_logloss: 0.45272
# [459]	valid_0's binary_logloss: 0.452646
# [460]	valid_0's binary_logloss: 0.452594
# [461]	valid_0's binary_logloss: 0.452524
# [462]	valid_0's binary_logloss: 0.452454
# [463]	valid_0's binary_logloss: 0.452382
# [464]	valid_0's binary_logloss: 0.45233
# [465]	valid_0's binary_logloss: 0.452261
# [466]	valid_0's binary_logloss: 0.452187
# [467]	valid_0's binary_logloss: 0.452117
# [468]	valid_0's binary_logloss: 0.452067
# [469]	valid_0's binary_logloss: 0.451996
# [470]	valid_0's binary_logloss: 0.451924
# [471]	valid_0's binary_logloss: 0.451853
# [472]	valid_0's binary_logloss: 0.451784
# [473]	valid_0's binary_logloss: 0.451711
# [474]	valid_0's binary_logloss: 0.45166
# [475]	valid_0's binary_logloss: 0.451591
# [476]	valid_0's binary_logloss: 0.451522
# [477]	valid_0's binary_logloss: 0.45145
# [478]	valid_0's binary_logloss: 0.451382
# [479]	valid_0's binary_logloss: 0.451315
# [480]	valid_0's binary_logloss: 0.451245
# [481]	valid_0's binary_logloss: 0.451177
# [482]	valid_0's binary_logloss: 0.451104
# [483]	valid_0's binary_logloss: 0.451035
# [484]	valid_0's binary_logloss: 0.450963
# [485]	valid_0's binary_logloss: 0.450893
# [486]	valid_0's binary_logloss: 0.450824
# [487]	valid_0's binary_logloss: 0.450774
# [488]	valid_0's binary_logloss: 0.450705
# [489]	valid_0's binary_logloss: 0.450634
# [490]	valid_0's binary_logloss: 0.450566
# [491]	valid_0's binary_logloss: 0.450498
# [492]	valid_0's binary_logloss: 0.450431
# [493]	valid_0's binary_logloss: 0.450382
# [494]	valid_0's binary_logloss: 0.450313
# [495]	valid_0's binary_logloss: 0.450247
# [496]	valid_0's binary_logloss: 0.450175
# [497]	valid_0's binary_logloss: 0.450109
# [498]	valid_0's binary_logloss: 0.450041
# [499]	valid_0's binary_logloss: 0.449973
# [500]	valid_0's binary_logloss: 0.449906
# [501]	valid_0's binary_logloss: 0.449838
# [502]	valid_0's binary_logloss: 0.449791
# [503]	valid_0's binary_logloss: 0.449723
# [504]	valid_0's binary_logloss: 0.449655
# [505]	valid_0's binary_logloss: 0.449589
# [506]	valid_0's binary_logloss: 0.449521
# [507]	valid_0's binary_logloss: 0.449454
# [508]	valid_0's binary_logloss: 0.449387
# [509]	valid_0's binary_logloss: 0.449321
# [510]	valid_0's binary_logloss: 0.449255
# [511]	valid_0's binary_logloss: 0.449189
# [512]	valid_0's binary_logloss: 0.449123
# [513]	valid_0's binary_logloss: 0.449076
# [514]	valid_0's binary_logloss: 0.449012
# [515]	valid_0's binary_logloss: 0.448946
# [516]	valid_0's binary_logloss: 0.448881
# [517]	valid_0's binary_logloss: 0.448815
# [518]	valid_0's binary_logloss: 0.448748
# [519]	valid_0's binary_logloss: 0.448681
# [520]	valid_0's binary_logloss: 0.448614
# [521]	valid_0's binary_logloss: 0.448551
# [522]	valid_0's binary_logloss: 0.448488
# [523]	valid_0's binary_logloss: 0.448424
# [524]	valid_0's binary_logloss: 0.448362
# [525]	valid_0's binary_logloss: 0.448295
# [526]	valid_0's binary_logloss: 0.448229
# [527]	valid_0's binary_logloss: 0.448168
# [528]	valid_0's binary_logloss: 0.448101
# [529]	valid_0's binary_logloss: 0.448039
# [530]	valid_0's binary_logloss: 0.447975
# [531]	valid_0's binary_logloss: 0.447911
# [532]	valid_0's binary_logloss: 0.447846
# [533]	valid_0's binary_logloss: 0.4478
# [534]	valid_0's binary_logloss: 0.447741
# [535]	valid_0's binary_logloss: 0.447674
# [536]	valid_0's binary_logloss: 0.44761
# [537]	valid_0's binary_logloss: 0.447565
# [538]	valid_0's binary_logloss: 0.447504
# [539]	valid_0's binary_logloss: 0.447441
# [540]	valid_0's binary_logloss: 0.447377
# [541]	valid_0's binary_logloss: 0.447316
# [542]	valid_0's binary_logloss: 0.447254
# [543]	valid_0's binary_logloss: 0.447208
# [544]	valid_0's binary_logloss: 0.447164
# [545]	valid_0's binary_logloss: 0.447105
# [546]	valid_0's binary_logloss: 0.447046
# [547]	valid_0's binary_logloss: 0.446982
# [548]	valid_0's binary_logloss: 0.44692
# [549]	valid_0's binary_logloss: 0.446858
# [550]	valid_0's binary_logloss: 0.446795
# [551]	valid_0's binary_logloss: 0.446735
# [552]	valid_0's binary_logloss: 0.446672
# [553]	valid_0's binary_logloss: 0.446609
# [554]	valid_0's binary_logloss: 0.446549
# [555]	valid_0's binary_logloss: 0.446504
# [556]	valid_0's binary_logloss: 0.446443
# [557]	valid_0's binary_logloss: 0.44638
# [558]	valid_0's binary_logloss: 0.446319
# [559]	valid_0's binary_logloss: 0.446258
# [560]	valid_0's binary_logloss: 0.446196
# [561]	valid_0's binary_logloss: 0.446135
# [562]	valid_0's binary_logloss: 0.446072
# [563]	valid_0's binary_logloss: 0.446014
# [564]	valid_0's binary_logloss: 0.445952
# [565]	valid_0's binary_logloss: 0.44589
# [566]	valid_0's binary_logloss: 0.44583
# [567]	valid_0's binary_logloss: 0.44577
# [568]	valid_0's binary_logloss: 0.445708
# [569]	valid_0's binary_logloss: 0.445648
# [570]	valid_0's binary_logloss: 0.445591
# [571]	valid_0's binary_logloss: 0.445531
# [572]	valid_0's binary_logloss: 0.44547
# [573]	valid_0's binary_logloss: 0.445412
# [574]	valid_0's binary_logloss: 0.445351
# [575]	valid_0's binary_logloss: 0.445293
# [576]	valid_0's binary_logloss: 0.445233
# [577]	valid_0's binary_logloss: 0.445176
# [578]	valid_0's binary_logloss: 0.445117
# [579]	valid_0's binary_logloss: 0.445076
# [580]	valid_0's binary_logloss: 0.445016
# [581]	valid_0's binary_logloss: 0.444956
# [582]	valid_0's binary_logloss: 0.444896
# [583]	valid_0's binary_logloss: 0.444838
# [584]	valid_0's binary_logloss: 0.444782
# [585]	valid_0's binary_logloss: 0.444724
# [586]	valid_0's binary_logloss: 0.444664
# [587]	valid_0's binary_logloss: 0.444607
# [588]	valid_0's binary_logloss: 0.444548
# [589]	valid_0's binary_logloss: 0.444492
# [590]	valid_0's binary_logloss: 0.444431
# [591]	valid_0's binary_logloss: 0.444373
# [592]	valid_0's binary_logloss: 0.444315
# [593]	valid_0's binary_logloss: 0.444258
# [594]	valid_0's binary_logloss: 0.444199
# [595]	valid_0's binary_logloss: 0.444145
# [596]	valid_0's binary_logloss: 0.444088
# [597]	valid_0's binary_logloss: 0.444031
# [598]	valid_0's binary_logloss: 0.443975
# [599]	valid_0's binary_logloss: 0.443934
# [600]	valid_0's binary_logloss: 0.443879
# [601]	valid_0's binary_logloss: 0.443821
# [602]	valid_0's binary_logloss: 0.443762
# [603]	valid_0's binary_logloss: 0.443706
# [604]	valid_0's binary_logloss: 0.44365
# [605]	valid_0's binary_logloss: 0.443611
# [606]	valid_0's binary_logloss: 0.443554
# [607]	valid_0's binary_logloss: 0.443497
# [608]	valid_0's binary_logloss: 0.44344
# [609]	valid_0's binary_logloss: 0.443385
# [610]	valid_0's binary_logloss: 0.443345
# [611]	valid_0's binary_logloss: 0.443289
# [612]	valid_0's binary_logloss: 0.443233
# [613]	valid_0's binary_logloss: 0.443177
# [614]	valid_0's binary_logloss: 0.443118
# [615]	valid_0's binary_logloss: 0.443062
# [616]	valid_0's binary_logloss: 0.443006
# [617]	valid_0's binary_logloss: 0.442964
# [618]	valid_0's binary_logloss: 0.442911
# [619]	valid_0's binary_logloss: 0.442857
# [620]	valid_0's binary_logloss: 0.442802
# [621]	valid_0's binary_logloss: 0.442745
# [622]	valid_0's binary_logloss: 0.442707
# [623]	valid_0's binary_logloss: 0.442651
# [624]	valid_0's binary_logloss: 0.442596
# [625]	valid_0's binary_logloss: 0.442541
# [626]	valid_0's binary_logloss: 0.442484
# [627]	valid_0's binary_logloss: 0.442446
# [628]	valid_0's binary_logloss: 0.442393
# [629]	valid_0's binary_logloss: 0.442335
# [630]	valid_0's binary_logloss: 0.442282
# [631]	valid_0's binary_logloss: 0.442226
# [632]	valid_0's binary_logloss: 0.442173
# [633]	valid_0's binary_logloss: 0.442123
# [634]	valid_0's binary_logloss: 0.442071
# [635]	valid_0's binary_logloss: 0.442016
# [636]	valid_0's binary_logloss: 0.441963
# [637]	valid_0's binary_logloss: 0.441909
# [638]	valid_0's binary_logloss: 0.441856
# [639]	valid_0's binary_logloss: 0.441801
# [640]	valid_0's binary_logloss: 0.441743
# [641]	valid_0's binary_logloss: 0.441689
# [642]	valid_0's binary_logloss: 0.441637
# [643]	valid_0's binary_logloss: 0.441585
# [644]	valid_0's binary_logloss: 0.441534
# [645]	valid_0's binary_logloss: 0.441481
# [646]	valid_0's binary_logloss: 0.441426
# [647]	valid_0's binary_logloss: 0.441372
# [648]	valid_0's binary_logloss: 0.441334
# [649]	valid_0's binary_logloss: 0.441281
# [650]	valid_0's binary_logloss: 0.44123
# [651]	valid_0's binary_logloss: 0.441177
# [652]	valid_0's binary_logloss: 0.441127
# [653]	valid_0's binary_logloss: 0.441071
# [654]	valid_0's binary_logloss: 0.441021
# [655]	valid_0's binary_logloss: 0.440984
# [656]	valid_0's binary_logloss: 0.44093
# [657]	valid_0's binary_logloss: 0.440893
# [658]	valid_0's binary_logloss: 0.44084
# [659]	valid_0's binary_logloss: 0.440788
# [660]	valid_0's binary_logloss: 0.440736
# [661]	valid_0's binary_logloss: 0.440683
# [662]	valid_0's binary_logloss: 0.440632
# [663]	valid_0's binary_logloss: 0.440594
# [664]	valid_0's binary_logloss: 0.440544
# [665]	valid_0's binary_logloss: 0.440495
# [666]	valid_0's binary_logloss: 0.440444
# [667]	valid_0's binary_logloss: 0.440393
# [668]	valid_0's binary_logloss: 0.440339
# [669]	valid_0's binary_logloss: 0.440287
# [670]	valid_0's binary_logloss: 0.440251
# [671]	valid_0's binary_logloss: 0.440203
# [672]	valid_0's binary_logloss: 0.440151
# [673]	valid_0's binary_logloss: 0.440101
# [674]	valid_0's binary_logloss: 0.440051
# [675]	valid_0's binary_logloss: 0.44
# [676]	valid_0's binary_logloss: 0.439947
# [677]	valid_0's binary_logloss: 0.439899
# [678]	valid_0's binary_logloss: 0.439851
# [679]	valid_0's binary_logloss: 0.439801
# [680]	valid_0's binary_logloss: 0.439747
# [681]	valid_0's binary_logloss: 0.439695
# [682]	valid_0's binary_logloss: 0.439644
# [683]	valid_0's binary_logloss: 0.439597
# [684]	valid_0's binary_logloss: 0.43955
# [685]	valid_0's binary_logloss: 0.439501
# [686]	valid_0's binary_logloss: 0.439452
# [687]	valid_0's binary_logloss: 0.439401
# [688]	valid_0's binary_logloss: 0.439353
# [689]	valid_0's binary_logloss: 0.439304
# [690]	valid_0's binary_logloss: 0.439253
# [691]	valid_0's binary_logloss: 0.439203
# [692]	valid_0's binary_logloss: 0.439153
# [693]	valid_0's binary_logloss: 0.439103
# [694]	valid_0's binary_logloss: 0.439069
# [695]	valid_0's binary_logloss: 0.43902
# [696]	valid_0's binary_logloss: 0.438972
# [697]	valid_0's binary_logloss: 0.438923
# [698]	valid_0's binary_logloss: 0.438881
# [699]	valid_0's binary_logloss: 0.438831
# [700]	valid_0's binary_logloss: 0.438782
# [701]	valid_0's binary_logloss: 0.438732
# [702]	valid_0's binary_logloss: 0.438685
# [703]	valid_0's binary_logloss: 0.438637
# [704]	valid_0's binary_logloss: 0.438591
# [705]	valid_0's binary_logloss: 0.438543
# [706]	valid_0's binary_logloss: 0.438496
# [707]	valid_0's binary_logloss: 0.438448
# [708]	valid_0's binary_logloss: 0.438402
# [709]	valid_0's binary_logloss: 0.438355
# [710]	valid_0's binary_logloss: 0.438308
# [711]	valid_0's binary_logloss: 0.438259
# [712]	valid_0's binary_logloss: 0.438213
# [713]	valid_0's binary_logloss: 0.438164
# [714]	valid_0's binary_logloss: 0.438117
# [715]	valid_0's binary_logloss: 0.438068
# [716]	valid_0's binary_logloss: 0.438023
# [717]	valid_0's binary_logloss: 0.437977
# [718]	valid_0's binary_logloss: 0.437929
# [719]	valid_0's binary_logloss: 0.437883
# [720]	valid_0's binary_logloss: 0.437835
# [721]	valid_0's binary_logloss: 0.437791
# [722]	valid_0's binary_logloss: 0.437746
# [723]	valid_0's binary_logloss: 0.4377
# [724]	valid_0's binary_logloss: 0.437653
# [725]	valid_0's binary_logloss: 0.437608
# [726]	valid_0's binary_logloss: 0.437562
# [727]	valid_0's binary_logloss: 0.437528
# [728]	valid_0's binary_logloss: 0.437483
# [729]	valid_0's binary_logloss: 0.437437
# [730]	valid_0's binary_logloss: 0.437404
# [731]	valid_0's binary_logloss: 0.437361
# [732]	valid_0's binary_logloss: 0.437318
# [733]	valid_0's binary_logloss: 0.437272
# [734]	valid_0's binary_logloss: 0.437228
# [735]	valid_0's binary_logloss: 0.437185
# [736]	valid_0's binary_logloss: 0.43714
# [737]	valid_0's binary_logloss: 0.437095
# [738]	valid_0's binary_logloss: 0.437051
# [739]	valid_0's binary_logloss: 0.437005
# [740]	valid_0's binary_logloss: 0.436959
# [741]	valid_0's binary_logloss: 0.436912
# [742]	valid_0's binary_logloss: 0.436868
# [743]	valid_0's binary_logloss: 0.436823
# [744]	valid_0's binary_logloss: 0.43678
# [745]	valid_0's binary_logloss: 0.436735
# [746]	valid_0's binary_logloss: 0.43669
# [747]	valid_0's binary_logloss: 0.43666
# [748]	valid_0's binary_logloss: 0.436615
# [749]	valid_0's binary_logloss: 0.43657
# [750]	valid_0's binary_logloss: 0.43653
# [751]	valid_0's binary_logloss: 0.436486
# [752]	valid_0's binary_logloss: 0.436442
# [753]	valid_0's binary_logloss: 0.436397
# [754]	valid_0's binary_logloss: 0.436349
# [755]	valid_0's binary_logloss: 0.436307
# [756]	valid_0's binary_logloss: 0.436262
# [757]	valid_0's binary_logloss: 0.436217
# [758]	valid_0's binary_logloss: 0.436174
# [759]	valid_0's binary_logloss: 0.436132
# [760]	valid_0's binary_logloss: 0.436087
# [761]	valid_0's binary_logloss: 0.436044
# [762]	valid_0's binary_logloss: 0.436001
# [763]	valid_0's binary_logloss: 0.435956
# [764]	valid_0's binary_logloss: 0.435914
# [765]	valid_0's binary_logloss: 0.435872
# [766]	valid_0's binary_logloss: 0.43583
# [767]	valid_0's binary_logloss: 0.435787
# [768]	valid_0's binary_logloss: 0.435755
# [769]	valid_0's binary_logloss: 0.435711
# [770]	valid_0's binary_logloss: 0.435669
# [771]	valid_0's binary_logloss: 0.435628
# [772]	valid_0's binary_logloss: 0.435599
# [773]	valid_0's binary_logloss: 0.435557
# [774]	valid_0's binary_logloss: 0.435513
# [775]	valid_0's binary_logloss: 0.435485
# [776]	valid_0's binary_logloss: 0.435443
# [777]	valid_0's binary_logloss: 0.435413
# [778]	valid_0's binary_logloss: 0.435381
# [779]	valid_0's binary_logloss: 0.435339
# [780]	valid_0's binary_logloss: 0.435298
# [781]	valid_0's binary_logloss: 0.435268
# [782]	valid_0's binary_logloss: 0.435227
# [783]	valid_0's binary_logloss: 0.435184
# [784]	valid_0's binary_logloss: 0.435141
# [785]	valid_0's binary_logloss: 0.435101
# [786]	valid_0's binary_logloss: 0.435056
# [787]	valid_0's binary_logloss: 0.435014
# [788]	valid_0's binary_logloss: 0.434971
# [789]	valid_0's binary_logloss: 0.43493
# [790]	valid_0's binary_logloss: 0.434891
# [791]	valid_0's binary_logloss: 0.434862
# [792]	valid_0's binary_logloss: 0.43482
# [793]	valid_0's binary_logloss: 0.434775
# [794]	valid_0's binary_logloss: 0.434736
# [795]	valid_0's binary_logloss: 0.434695
# [796]	valid_0's binary_logloss: 0.434655
# [797]	valid_0's binary_logloss: 0.434614
# [798]	valid_0's binary_logloss: 0.434573
# [799]	valid_0's binary_logloss: 0.434547
# [800]	valid_0's binary_logloss: 0.434506
# [801]	valid_0's binary_logloss: 0.434467
# [802]	valid_0's binary_logloss: 0.434432
# [803]	valid_0's binary_logloss: 0.434391
# [804]	valid_0's binary_logloss: 0.434353
# [805]	valid_0's binary_logloss: 0.434324
# [806]	valid_0's binary_logloss: 0.434282
# [807]	valid_0's binary_logloss: 0.434253
# [808]	valid_0's binary_logloss: 0.434213
# [809]	valid_0's binary_logloss: 0.434178
# [810]	valid_0's binary_logloss: 0.434141
# [811]	valid_0's binary_logloss: 0.434101
# [812]	valid_0's binary_logloss: 0.434062
# [813]	valid_0's binary_logloss: 0.434022
# [814]	valid_0's binary_logloss: 0.433987
# [815]	valid_0's binary_logloss: 0.433949
# [816]	valid_0's binary_logloss: 0.433916
# [817]	valid_0's binary_logloss: 0.433879
# [818]	valid_0's binary_logloss: 0.433837
# [819]	valid_0's binary_logloss: 0.433799
# [820]	valid_0's binary_logloss: 0.433761
# [821]	valid_0's binary_logloss: 0.433719
# [822]	valid_0's binary_logloss: 0.433678
# [823]	valid_0's binary_logloss: 0.433637
# [824]	valid_0's binary_logloss: 0.433601
# [825]	valid_0's binary_logloss: 0.433575
# [826]	valid_0's binary_logloss: 0.43354
# [827]	valid_0's binary_logloss: 0.4335
# [828]	valid_0's binary_logloss: 0.433461
# [829]	valid_0's binary_logloss: 0.433423
# [830]	valid_0's binary_logloss: 0.433386
# [831]	valid_0's binary_logloss: 0.433345
# [832]	valid_0's binary_logloss: 0.433307
# [833]	valid_0's binary_logloss: 0.43327
# [834]	valid_0's binary_logloss: 0.433229
# [835]	valid_0's binary_logloss: 0.433203
# [836]	valid_0's binary_logloss: 0.433164
# [837]	valid_0's binary_logloss: 0.433139
# [838]	valid_0's binary_logloss: 0.433103
# [839]	valid_0's binary_logloss: 0.433065
# [840]	valid_0's binary_logloss: 0.433026
# [841]	valid_0's binary_logloss: 0.432987
# [842]	valid_0's binary_logloss: 0.432948
# [843]	valid_0's binary_logloss: 0.432921
# [844]	valid_0's binary_logloss: 0.432886
# [845]	valid_0's binary_logloss: 0.432847
# [846]	valid_0's binary_logloss: 0.432809
# [847]	valid_0's binary_logloss: 0.432785
# [848]	valid_0's binary_logloss: 0.43276
# [849]	valid_0's binary_logloss: 0.432724
# [850]	valid_0's binary_logloss: 0.432687
# [851]	valid_0's binary_logloss: 0.432648
# [852]	valid_0's binary_logloss: 0.43261
# [853]	valid_0's binary_logloss: 0.432572
# [854]	valid_0's binary_logloss: 0.432536
# [855]	valid_0's binary_logloss: 0.432497
# [856]	valid_0's binary_logloss: 0.43246
# [857]	valid_0's binary_logloss: 0.43242
# [858]	valid_0's binary_logloss: 0.432382
# [859]	valid_0's binary_logloss: 0.432344
# [860]	valid_0's binary_logloss: 0.432308
# [861]	valid_0's binary_logloss: 0.43227
# [862]	valid_0's binary_logloss: 0.432234
# [863]	valid_0's binary_logloss: 0.432195
# [864]	valid_0's binary_logloss: 0.432157
# [865]	valid_0's binary_logloss: 0.432121
# [866]	valid_0's binary_logloss: 0.432086
# [867]	valid_0's binary_logloss: 0.43205
# [868]	valid_0's binary_logloss: 0.432016
# [869]	valid_0's binary_logloss: 0.431978
# [870]	valid_0's binary_logloss: 0.431951
# [871]	valid_0's binary_logloss: 0.431914
# [872]	valid_0's binary_logloss: 0.431886
# [873]	valid_0's binary_logloss: 0.43185
# [874]	valid_0's binary_logloss: 0.431813
# [875]	valid_0's binary_logloss: 0.431777
# [876]	valid_0's binary_logloss: 0.431741
# [877]	valid_0's binary_logloss: 0.431715
# [878]	valid_0's binary_logloss: 0.43168
# [879]	valid_0's binary_logloss: 0.431646
# [880]	valid_0's binary_logloss: 0.431611
# [881]	valid_0's binary_logloss: 0.431576
# [882]	valid_0's binary_logloss: 0.431541
# [883]	valid_0's binary_logloss: 0.431502
# [884]	valid_0's binary_logloss: 0.43147
# [885]	valid_0's binary_logloss: 0.431435
# [886]	valid_0's binary_logloss: 0.431398
# [887]	valid_0's binary_logloss: 0.431362
# [888]	valid_0's binary_logloss: 0.431327
# [889]	valid_0's binary_logloss: 0.431291
# [890]	valid_0's binary_logloss: 0.431256
# [891]	valid_0's binary_logloss: 0.431223
# [892]	valid_0's binary_logloss: 0.431184
# [893]	valid_0's binary_logloss: 0.431152
# [894]	valid_0's binary_logloss: 0.431117
# [895]	valid_0's binary_logloss: 0.431082
# [896]	valid_0's binary_logloss: 0.431046
# [897]	valid_0's binary_logloss: 0.431024
# [898]	valid_0's binary_logloss: 0.430989
# [899]	valid_0's binary_logloss: 0.430954
# [900]	valid_0's binary_logloss: 0.430921
# [901]	valid_0's binary_logloss: 0.430887
# [902]	valid_0's binary_logloss: 0.430852
# [903]	valid_0's binary_logloss: 0.430818
# [904]	valid_0's binary_logloss: 0.430785
# [905]	valid_0's binary_logloss: 0.430751
# [906]	valid_0's binary_logloss: 0.430715
# [907]	valid_0's binary_logloss: 0.430681
# [908]	valid_0's binary_logloss: 0.430655
# [909]	valid_0's binary_logloss: 0.43062
# [910]	valid_0's binary_logloss: 0.430585
# [911]	valid_0's binary_logloss: 0.430549
# [912]	valid_0's binary_logloss: 0.430515
# [913]	valid_0's binary_logloss: 0.43048
# [914]	valid_0's binary_logloss: 0.430458
# [915]	valid_0's binary_logloss: 0.430425
# [916]	valid_0's binary_logloss: 0.430393
# [917]	valid_0's binary_logloss: 0.430357
# [918]	valid_0's binary_logloss: 0.430332
# [919]	valid_0's binary_logloss: 0.430307
# [920]	valid_0's binary_logloss: 0.430273
# [921]	valid_0's binary_logloss: 0.430238
# [922]	valid_0's binary_logloss: 0.430207
# [923]	valid_0's binary_logloss: 0.430173
# [924]	valid_0's binary_logloss: 0.430143
# [925]	valid_0's binary_logloss: 0.43011
# [926]	valid_0's binary_logloss: 0.430079
# [927]	valid_0's binary_logloss: 0.430046
# [928]	valid_0's binary_logloss: 0.430013
# [929]	valid_0's binary_logloss: 0.429985
# [930]	valid_0's binary_logloss: 0.429951
# [931]	valid_0's binary_logloss: 0.429916
# [932]	valid_0's binary_logloss: 0.429884
# [933]	valid_0's binary_logloss: 0.429851
# [934]	valid_0's binary_logloss: 0.429821
# [935]	valid_0's binary_logloss: 0.429787
# [936]	valid_0's binary_logloss: 0.429755
# [937]	valid_0's binary_logloss: 0.429721
# [938]	valid_0's binary_logloss: 0.42969
# [939]	valid_0's binary_logloss: 0.429667
# [940]	valid_0's binary_logloss: 0.429635
# [941]	valid_0's binary_logloss: 0.429603
# [942]	valid_0's binary_logloss: 0.429572
# [943]	valid_0's binary_logloss: 0.429549
# [944]	valid_0's binary_logloss: 0.429515
# [945]	valid_0's binary_logloss: 0.429482
# [946]	valid_0's binary_logloss: 0.429449
# [947]	valid_0's binary_logloss: 0.42942
# [948]	valid_0's binary_logloss: 0.429389
# [949]	valid_0's binary_logloss: 0.429358
# [950]	valid_0's binary_logloss: 0.429328
# [951]	valid_0's binary_logloss: 0.429297
# [952]	valid_0's binary_logloss: 0.429264
# [953]	valid_0's binary_logloss: 0.429232
# [954]	valid_0's binary_logloss: 0.42921
# [955]	valid_0's binary_logloss: 0.429178
# [956]	valid_0's binary_logloss: 0.429154
# [957]	valid_0's binary_logloss: 0.429123
# [958]	valid_0's binary_logloss: 0.429091
# [959]	valid_0's binary_logloss: 0.429059
# [960]	valid_0's binary_logloss: 0.429038
# [961]	valid_0's binary_logloss: 0.429007
# [962]	valid_0's binary_logloss: 0.428975
# [963]	valid_0's binary_logloss: 0.428945
# [964]	valid_0's binary_logloss: 0.428924
# [965]	valid_0's binary_logloss: 0.428894
# [966]	valid_0's binary_logloss: 0.428862
# [967]	valid_0's binary_logloss: 0.42883
# [968]	valid_0's binary_logloss: 0.428799
# [969]	valid_0's binary_logloss: 0.428777
# [970]	valid_0's binary_logloss: 0.428746
# [971]	valid_0's binary_logloss: 0.428713
# [972]	valid_0's binary_logloss: 0.428681
# [973]	valid_0's binary_logloss: 0.428652
# [974]	valid_0's binary_logloss: 0.428621
# [975]	valid_0's binary_logloss: 0.428589
# [976]	valid_0's binary_logloss: 0.428557
# [977]	valid_0's binary_logloss: 0.428527
# [978]	valid_0's binary_logloss: 0.428499
# [979]	valid_0's binary_logloss: 0.428467
# [980]	valid_0's binary_logloss: 0.428436
# [981]	valid_0's binary_logloss: 0.428404
# [982]	valid_0's binary_logloss: 0.428373
# [983]	valid_0's binary_logloss: 0.428342
# [984]	valid_0's binary_logloss: 0.428311
# [985]	valid_0's binary_logloss: 0.42829
# [986]	valid_0's binary_logloss: 0.428259
# [987]	valid_0's binary_logloss: 0.428232
# [988]	valid_0's binary_logloss: 0.42821
# [989]	valid_0's binary_logloss: 0.428178
# [990]	valid_0's binary_logloss: 0.428148
# [991]	valid_0's binary_logloss: 0.428128
# [992]	valid_0's binary_logloss: 0.428099
# [993]	valid_0's binary_logloss: 0.428069
# [994]	valid_0's binary_logloss: 0.42805
# [995]	valid_0's binary_logloss: 0.42802
# [996]	valid_0's binary_logloss: 0.42799
# [997]	valid_0's binary_logloss: 0.427971
# [998]	valid_0's binary_logloss: 0.427949
# [999]	valid_0's binary_logloss: 0.427923
# [1000]	valid_0's binary_logloss: 0.427893
# [1001]	valid_0's binary_logloss: 0.427863
# [1002]	valid_0's binary_logloss: 0.427833
# [1003]	valid_0's binary_logloss: 0.427803
# [1004]	valid_0's binary_logloss: 0.427773
# [1005]	valid_0's binary_logloss: 0.427743
# [1006]	valid_0's binary_logloss: 0.427714
# [1007]	valid_0's binary_logloss: 0.427684
# [1008]	valid_0's binary_logloss: 0.427653
# [1009]	valid_0's binary_logloss: 0.427624
# [1010]	valid_0's binary_logloss: 0.427594
# [1011]	valid_0's binary_logloss: 0.427564
# [1012]	valid_0's binary_logloss: 0.427534
# [1013]	valid_0's binary_logloss: 0.427504
# [1014]	valid_0's binary_logloss: 0.427474
# [1015]	valid_0's binary_logloss: 0.427449
# [1016]	valid_0's binary_logloss: 0.427419
# [1017]	valid_0's binary_logloss: 0.42739
# [1018]	valid_0's binary_logloss: 0.42737
# [1019]	valid_0's binary_logloss: 0.42735
# [1020]	valid_0's binary_logloss: 0.427321
# [1021]	valid_0's binary_logloss: 0.427291
# [1022]	valid_0's binary_logloss: 0.427264
# [1023]	valid_0's binary_logloss: 0.427235
# [1024]	valid_0's binary_logloss: 0.427206
# [1025]	valid_0's binary_logloss: 0.427179
# [1026]	valid_0's binary_logloss: 0.427155
# [1027]	valid_0's binary_logloss: 0.427127
# [1028]	valid_0's binary_logloss: 0.427099
# [1029]	valid_0's binary_logloss: 0.427071
# [1030]	valid_0's binary_logloss: 0.427043
# [1031]	valid_0's binary_logloss: 0.427017
# [1032]	valid_0's binary_logloss: 0.426987
# [1033]	valid_0's binary_logloss: 0.426959
# [1034]	valid_0's binary_logloss: 0.426928
# [1035]	valid_0's binary_logloss: 0.4269
# [1036]	valid_0's binary_logloss: 0.426871
# [1037]	valid_0's binary_logloss: 0.426846
# [1038]	valid_0's binary_logloss: 0.426817
# [1039]	valid_0's binary_logloss: 0.426785
# [1040]	valid_0's binary_logloss: 0.426755
# [1041]	valid_0's binary_logloss: 0.426728
# [1042]	valid_0's binary_logloss: 0.4267
# [1043]	valid_0's binary_logloss: 0.426681
# [1044]	valid_0's binary_logloss: 0.426655
# [1045]	valid_0's binary_logloss: 0.426628
# [1046]	valid_0's binary_logloss: 0.426603
# [1047]	valid_0's binary_logloss: 0.426577
# [1048]	valid_0's binary_logloss: 0.426549
# [1049]	valid_0's binary_logloss: 0.426529
# [1050]	valid_0's binary_logloss: 0.426505
# [1051]	valid_0's binary_logloss: 0.42648
# [1052]	valid_0's binary_logloss: 0.426455
# [1053]	valid_0's binary_logloss: 0.42643
# [1054]	valid_0's binary_logloss: 0.426404
# [1055]	valid_0's binary_logloss: 0.426377
# [1056]	valid_0's binary_logloss: 0.42635
# [1057]	valid_0's binary_logloss: 0.426331
# [1058]	valid_0's binary_logloss: 0.426305
# [1059]	valid_0's binary_logloss: 0.42628
# [1060]	valid_0's binary_logloss: 0.426254
# [1061]	valid_0's binary_logloss: 0.426225
# [1062]	valid_0's binary_logloss: 0.426199
# [1063]	valid_0's binary_logloss: 0.426172
# [1064]	valid_0's binary_logloss: 0.426145
# [1065]	valid_0's binary_logloss: 0.42612
# [1066]	valid_0's binary_logloss: 0.426101
# [1067]	valid_0's binary_logloss: 0.426074
# [1068]	valid_0's binary_logloss: 0.426049
# [1069]	valid_0's binary_logloss: 0.426019
# [1070]	valid_0's binary_logloss: 0.425992
# [1071]	valid_0's binary_logloss: 0.425966
# [1072]	valid_0's binary_logloss: 0.42594
# [1073]	valid_0's binary_logloss: 0.425913
# [1074]	valid_0's binary_logloss: 0.425888
# [1075]	valid_0's binary_logloss: 0.425859
# [1076]	valid_0's binary_logloss: 0.425832
# [1077]	valid_0's binary_logloss: 0.425808
# [1078]	valid_0's binary_logloss: 0.425783
# [1079]	valid_0's binary_logloss: 0.425758
# [1080]	valid_0's binary_logloss: 0.425731
# [1081]	valid_0's binary_logloss: 0.425705
# [1082]	valid_0's binary_logloss: 0.425678
# [1083]	valid_0's binary_logloss: 0.42566
# [1084]	valid_0's binary_logloss: 0.425633
# [1085]	valid_0's binary_logloss: 0.425609
# [1086]	valid_0's binary_logloss: 0.425585
# [1087]	valid_0's binary_logloss: 0.425558
# [1088]	valid_0's binary_logloss: 0.425541
# [1089]	valid_0's binary_logloss: 0.425516
# [1090]	valid_0's binary_logloss: 0.425489
# [1091]	valid_0's binary_logloss: 0.425463
# [1092]	valid_0's binary_logloss: 0.425439
# [1093]	valid_0's binary_logloss: 0.425415
# [1094]	valid_0's binary_logloss: 0.425388
# [1095]	valid_0's binary_logloss: 0.425362
# [1096]	valid_0's binary_logloss: 0.425336
# [1097]	valid_0's binary_logloss: 0.425311
# [1098]	valid_0's binary_logloss: 0.425293
# [1099]	valid_0's binary_logloss: 0.425267
# [1100]	valid_0's binary_logloss: 0.425242
# [1101]	valid_0's binary_logloss: 0.425216
# [1102]	valid_0's binary_logloss: 0.425193
# [1103]	valid_0's binary_logloss: 0.425169
# [1104]	valid_0's binary_logloss: 0.425145
# [1105]	valid_0's binary_logloss: 0.42512
# [1106]	valid_0's binary_logloss: 0.425097
# [1107]	valid_0's binary_logloss: 0.425071
# [1108]	valid_0's binary_logloss: 0.425047
# [1109]	valid_0's binary_logloss: 0.425021
# [1110]	valid_0's binary_logloss: 0.424999
# [1111]	valid_0's binary_logloss: 0.424972
# [1112]	valid_0's binary_logloss: 0.424948
# [1113]	valid_0's binary_logloss: 0.424927
# [1114]	valid_0's binary_logloss: 0.424902
# [1115]	valid_0's binary_logloss: 0.424879
# [1116]	valid_0's binary_logloss: 0.424852
# [1117]	valid_0's binary_logloss: 0.424827
# [1118]	valid_0's binary_logloss: 0.424809
# [1119]	valid_0's binary_logloss: 0.424784
# [1120]	valid_0's binary_logloss: 0.424758
# [1121]	valid_0's binary_logloss: 0.424732
# [1122]	valid_0's binary_logloss: 0.42471
# [1123]	valid_0's binary_logloss: 0.424687
# [1124]	valid_0's binary_logloss: 0.424669
# [1125]	valid_0's binary_logloss: 0.424647
# [1126]	valid_0's binary_logloss: 0.424622
# [1127]	valid_0's binary_logloss: 0.424598
# [1128]	valid_0's binary_logloss: 0.424573
# [1129]	valid_0's binary_logloss: 0.42455
# [1130]	valid_0's binary_logloss: 0.424528
# [1131]	valid_0's binary_logloss: 0.424504
# [1132]	valid_0's binary_logloss: 0.424481
# [1133]	valid_0's binary_logloss: 0.424456
# [1134]	valid_0's binary_logloss: 0.424432
# [1135]	valid_0's binary_logloss: 0.424407
# [1136]	valid_0's binary_logloss: 0.424384
# [1137]	valid_0's binary_logloss: 0.424363
# [1138]	valid_0's binary_logloss: 0.424339
# [1139]	valid_0's binary_logloss: 0.424314
# [1140]	valid_0's binary_logloss: 0.42429
# [1141]	valid_0's binary_logloss: 0.424267
# [1142]	valid_0's binary_logloss: 0.424246
# [1143]	valid_0's binary_logloss: 0.424223
# [1144]	valid_0's binary_logloss: 0.4242
# [1145]	valid_0's binary_logloss: 0.424175
# [1146]	valid_0's binary_logloss: 0.424156
# [1147]	valid_0's binary_logloss: 0.424136
# [1148]	valid_0's binary_logloss: 0.424113
# [1149]	valid_0's binary_logloss: 0.424089
# [1150]	valid_0's binary_logloss: 0.42407
# [1151]	valid_0's binary_logloss: 0.424046
# [1152]	valid_0's binary_logloss: 0.424025
# [1153]	valid_0's binary_logloss: 0.424005
# [1154]	valid_0's binary_logloss: 0.42398
# [1155]	valid_0's binary_logloss: 0.423957
# [1156]	valid_0's binary_logloss: 0.423932
# [1157]	valid_0's binary_logloss: 0.42391
# [1158]	valid_0's binary_logloss: 0.423888
# [1159]	valid_0's binary_logloss: 0.423864
# ...
# [3705]	valid_0's binary_logloss: 0.407813
# [3706]	valid_0's binary_logloss: 0.40781
# [3707]	valid_0's binary_logloss: 0.407808
# [3708]	valid_0's binary_logloss: 0.407807
# [3709]	valid_0's binary_logloss: 0.407809
# [3710]	valid_0's binary_logloss: 0.407807
# [3711]	valid_0's binary_logloss: 0.407807
# [3712]	valid_0's binary_logloss: 0.407806
# [3713]	valid_0's binary_logloss: 0.407805
# [3714]	valid_0's binary_logloss: 0.407805
# [3715]	valid_0's binary_logloss: 0.407803
# [3716]	valid_0's binary_logloss: 0.407804
# [3717]	valid_0's binary_logloss: 0.407802
# [3718]	valid_0's binary_logloss: 0.4078
# [3719]	valid_0's binary_logloss: 0.4078
# [3720]	valid_0's binary_logloss: 0.407804
# [3721]	valid_0's binary_logloss: 0.407802
# [3722]	valid_0's binary_logloss: 0.407799
# [3723]	valid_0's binary_logloss: 0.407797
# [3724]	valid_0's binary_logloss: 0.407795
# [3725]	valid_0's binary_logloss: 0.407796
# [3726]	valid_0's binary_logloss: 0.407795
# [3727]	valid_0's binary_logloss: 0.407792
# [3728]	valid_0's binary_logloss: 0.407791
# [3729]	valid_0's binary_logloss: 0.407791
# [3730]	valid_0's binary_logloss: 0.40779
# [3731]	valid_0's binary_logloss: 0.407789
# [3732]	valid_0's binary_logloss: 0.407788
# [3733]	valid_0's binary_logloss: 0.407787
# [3734]	valid_0's binary_logloss: 0.407789
# [3735]	valid_0's binary_logloss: 0.407787
# [3736]	valid_0's binary_logloss: 0.407787
# [3737]	valid_0's binary_logloss: 0.407786
# [3738]	valid_0's binary_logloss: 0.407784
# [3739]	valid_0's binary_logloss: 0.407782
# [3740]	valid_0's binary_logloss: 0.40778
# [3741]	valid_0's binary_logloss: 0.407777
# [3742]	valid_0's binary_logloss: 0.407779
# [3743]	valid_0's binary_logloss: 0.407777
# [3744]	valid_0's binary_logloss: 0.407775
# [3745]	valid_0's binary_logloss: 0.407773
# [3746]	valid_0's binary_logloss: 0.407772
# [3747]	valid_0's binary_logloss: 0.407772
# [3748]	valid_0's binary_logloss: 0.407769
# [3749]	valid_0's binary_logloss: 0.40777
# [3750]	valid_0's binary_logloss: 0.407766
# [3751]	valid_0's binary_logloss: 0.407765
# [3752]	valid_0's binary_logloss: 0.407764
# [3753]	valid_0's binary_logloss: 0.407764
# [3754]	valid_0's binary_logloss: 0.407761
# [3755]	valid_0's binary_logloss: 0.40776
# [3756]	valid_0's binary_logloss: 0.407757
# [3757]	valid_0's binary_logloss: 0.407753
# [3758]	valid_0's binary_logloss: 0.407753
# [3759]	valid_0's binary_logloss: 0.407754
# [3760]	valid_0's binary_logloss: 0.407755
# [3761]	valid_0's binary_logloss: 0.407755
# [3762]	valid_0's binary_logloss: 0.407755
# [3763]	valid_0's binary_logloss: 0.407754
# [3764]	valid_0's binary_logloss: 0.407754
# [3765]	valid_0's binary_logloss: 0.407753
# [3766]	valid_0's binary_logloss: 0.407752
# [3767]	valid_0's binary_logloss: 0.407751
# [3768]	valid_0's binary_logloss: 0.407751
# [3769]	valid_0's binary_logloss: 0.407749
# [3770]	valid_0's binary_logloss: 0.407749
# [3771]	valid_0's binary_logloss: 0.407747
# [3772]	valid_0's binary_logloss: 0.407744
# [3773]	valid_0's binary_logloss: 0.407744
# [3774]	valid_0's binary_logloss: 0.407744
# [3775]	valid_0's binary_logloss: 0.407743
# [3776]	valid_0's binary_logloss: 0.407742
# [3777]	valid_0's binary_logloss: 0.407736
# [3778]	valid_0's binary_logloss: 0.407736
# [3779]	valid_0's binary_logloss: 0.407737
# [3780]	valid_0's binary_logloss: 0.407733
# [3781]	valid_0's binary_logloss: 0.407735
# [3782]	valid_0's binary_logloss: 0.407736
# [3783]	valid_0's binary_logloss: 0.407735
# [3784]	valid_0's binary_logloss: 0.407734
# [3785]	valid_0's binary_logloss: 0.407732
# [3786]	valid_0's binary_logloss: 0.407732
# [3787]	valid_0's binary_logloss: 0.407728
# [3788]	valid_0's binary_logloss: 0.407727
# [3789]	valid_0's binary_logloss: 0.407727
# [3790]	valid_0's binary_logloss: 0.407725
# [3791]	valid_0's binary_logloss: 0.407724
# [3792]	valid_0's binary_logloss: 0.407722
# [3793]	valid_0's binary_logloss: 0.407722
# [3794]	valid_0's binary_logloss: 0.407722
# [3795]	valid_0's binary_logloss: 0.407721
# [3796]	valid_0's binary_logloss: 0.407721
# [3797]	valid_0's binary_logloss: 0.40772
# [3798]	valid_0's binary_logloss: 0.407721
# [3799]	valid_0's binary_logloss: 0.40772
# [3800]	valid_0's binary_logloss: 0.407719
# [3801]	valid_0's binary_logloss: 0.407718
# [3802]	valid_0's binary_logloss: 0.407716
# [3803]	valid_0's binary_logloss: 0.407713
# [3804]	valid_0's binary_logloss: 0.407714
# [3805]	valid_0's binary_logloss: 0.407712
# [3806]	valid_0's binary_logloss: 0.407712
# [3807]	valid_0's binary_logloss: 0.407713
# [3808]	valid_0's binary_logloss: 0.407712
# [3809]	valid_0's binary_logloss: 0.407711
# [3810]	valid_0's binary_logloss: 0.40771
# [3811]	valid_0's binary_logloss: 0.407709
# [3812]	valid_0's binary_logloss: 0.407711
# [3813]	valid_0's binary_logloss: 0.407709
# [3814]	valid_0's binary_logloss: 0.407706
# [3815]	valid_0's binary_logloss: 0.407704
# [3816]	valid_0's binary_logloss: 0.407704
# [3817]	valid_0's binary_logloss: 0.407705
# [3818]	valid_0's binary_logloss: 0.407701
# [3819]	valid_0's binary_logloss: 0.407701
# [3820]	valid_0's binary_logloss: 0.4077
# [3821]	valid_0's binary_logloss: 0.407699
# [3822]	valid_0's binary_logloss: 0.407698
# [3823]	valid_0's binary_logloss: 0.407697
# [3824]	valid_0's binary_logloss: 0.407695
# [3825]	valid_0's binary_logloss: 0.407694
# [3826]	valid_0's binary_logloss: 0.407694
# [3827]	valid_0's binary_logloss: 0.407695
# [3828]	valid_0's binary_logloss: 0.407693
# [3829]	valid_0's binary_logloss: 0.407693
# [3830]	valid_0's binary_logloss: 0.407693
# [3831]	valid_0's binary_logloss: 0.407693
# [3832]	valid_0's binary_logloss: 0.407692
# [3833]	valid_0's binary_logloss: 0.407693
# [3834]	valid_0's binary_logloss: 0.407695
# [3835]	valid_0's binary_logloss: 0.407694
# [3836]	valid_0's binary_logloss: 0.407694
# [3837]	valid_0's binary_logloss: 0.407696
# [3838]	valid_0's binary_logloss: 0.407696
# [3839]	valid_0's binary_logloss: 0.407697
# [3840]	valid_0's binary_logloss: 0.407697
# [3841]	valid_0's binary_logloss: 0.407699
# [3842]	valid_0's binary_logloss: 0.4077
# [3843]	valid_0's binary_logloss: 0.4077
# [3844]	valid_0's binary_logloss: 0.407698
# [3845]	valid_0's binary_logloss: 0.407698
# [3846]	valid_0's binary_logloss: 0.407696
# [3847]	valid_0's binary_logloss: 0.407696
# [3848]	valid_0's binary_logloss: 0.407695
# [3849]	valid_0's binary_logloss: 0.407694
# [3850]	valid_0's binary_logloss: 0.407693
# [3851]	valid_0's binary_logloss: 0.407693
# [3852]	valid_0's binary_logloss: 0.407689
# [3853]	valid_0's binary_logloss: 0.407687
# [3854]	valid_0's binary_logloss: 0.407687
# [3855]	valid_0's binary_logloss: 0.407686
# [3856]	valid_0's binary_logloss: 0.407684
# [3857]	valid_0's binary_logloss: 0.407683
# [3858]	valid_0's binary_logloss: 0.407683
# [3859]	valid_0's binary_logloss: 0.407681
# [3860]	valid_0's binary_logloss: 0.407679
# [3861]	valid_0's binary_logloss: 0.40768
# [3862]	valid_0's binary_logloss: 0.40768
# [3863]	valid_0's binary_logloss: 0.40768
# [3864]	valid_0's binary_logloss: 0.407679
# [3865]	valid_0's binary_logloss: 0.407679
# [3866]	valid_0's binary_logloss: 0.407678
# [3867]	valid_0's binary_logloss: 0.407679
# [3868]	valid_0's binary_logloss: 0.407677
# [3869]	valid_0's binary_logloss: 0.407677
# [3870]	valid_0's binary_logloss: 0.407676
# [3871]	valid_0's binary_logloss: 0.407674
# [3872]	valid_0's binary_logloss: 0.407673
# [3873]	valid_0's binary_logloss: 0.407672
# [3874]	valid_0's binary_logloss: 0.407673
# [3875]	valid_0's binary_logloss: 0.407673
# [3876]	valid_0's binary_logloss: 0.407669
# [3877]	valid_0's binary_logloss: 0.407667
# [3878]	valid_0's binary_logloss: 0.407665
# [3879]	valid_0's binary_logloss: 0.407666
# [3880]	valid_0's binary_logloss: 0.407667
# [3881]	valid_0's binary_logloss: 0.407665
# [3882]	valid_0's binary_logloss: 0.407664
# [3883]	valid_0's binary_logloss: 0.407664
# [3884]	valid_0's binary_logloss: 0.407663
# [3885]	valid_0's binary_logloss: 0.407662
# [3886]	valid_0's binary_logloss: 0.407663
# [3887]	valid_0's binary_logloss: 0.407664
# [3888]	valid_0's binary_logloss: 0.407663
# [3889]	valid_0's binary_logloss: 0.407663
# [3890]	valid_0's binary_logloss: 0.407659
# [3891]	valid_0's binary_logloss: 0.407659
# [3892]	valid_0's binary_logloss: 0.40766
# [3893]	valid_0's binary_logloss: 0.407661
# [3894]	valid_0's binary_logloss: 0.407661
# [3895]	valid_0's binary_logloss: 0.407661
# [3896]	valid_0's binary_logloss: 0.40766
# [3897]	valid_0's binary_logloss: 0.407658
# [3898]	valid_0's binary_logloss: 0.407658
# [3899]	valid_0's binary_logloss: 0.407656
# [3900]	valid_0's binary_logloss: 0.407657
# [3901]	valid_0's binary_logloss: 0.407657
# [3902]	valid_0's binary_logloss: 0.407658
# [3903]	valid_0's binary_logloss: 0.407656
# [3904]	valid_0's binary_logloss: 0.407655
# [3905]	valid_0's binary_logloss: 0.407655
# [3906]	valid_0's binary_logloss: 0.407655
# [3907]	valid_0's binary_logloss: 0.407655
# [3908]	valid_0's binary_logloss: 0.407655
# [3909]	valid_0's binary_logloss: 0.407658
# [3910]	valid_0's binary_logloss: 0.407655
# [3911]	valid_0's binary_logloss: 0.407656
# [3912]	valid_0's binary_logloss: 0.407657
# [3913]	valid_0's binary_logloss: 0.407655
# [3914]	valid_0's binary_logloss: 0.407654
# [3915]	valid_0's binary_logloss: 0.407655
# [3916]	valid_0's binary_logloss: 0.40765
# [3917]	valid_0's binary_logloss: 0.40765
# [3918]	valid_0's binary_logloss: 0.407648
# [3919]	valid_0's binary_logloss: 0.407644
# [3920]	valid_0's binary_logloss: 0.407647
# [3921]	valid_0's binary_logloss: 0.407649
# [3922]	valid_0's binary_logloss: 0.407651
# [3923]	valid_0's binary_logloss: 0.407651
# [3924]	valid_0's binary_logloss: 0.40765
# [3925]	valid_0's binary_logloss: 0.407651
# [3926]	valid_0's binary_logloss: 0.40765
# [3927]	valid_0's binary_logloss: 0.407652
# [3928]	valid_0's binary_logloss: 0.407653
# [3929]	valid_0's binary_logloss: 0.407653
# [3930]	valid_0's binary_logloss: 0.407656
# [3931]	valid_0's binary_logloss: 0.407655
# [3932]	valid_0's binary_logloss: 0.407654
# [3933]	valid_0's binary_logloss: 0.407655
# [3934]	valid_0's binary_logloss: 0.407655
# [3935]	valid_0's binary_logloss: 0.407653
# [3936]	valid_0's binary_logloss: 0.407653
# [3937]	valid_0's binary_logloss: 0.407654
# [3938]	valid_0's binary_logloss: 0.407654
# [3939]	valid_0's binary_logloss: 0.40765
# [3940]	valid_0's binary_logloss: 0.407649
# [3941]	valid_0's binary_logloss: 0.407649
# [3942]	valid_0's binary_logloss: 0.407649
# [3943]	valid_0's binary_logloss: 0.407649
# [3944]	valid_0's binary_logloss: 0.407646
# [3945]	valid_0's binary_logloss: 0.407643
# [3946]	valid_0's binary_logloss: 0.407644
# [3947]	valid_0's binary_logloss: 0.407643
# [3948]	valid_0's binary_logloss: 0.407643
# [3949]	valid_0's binary_logloss: 0.407644
# [3950]	valid_0's binary_logloss: 0.407641
# [3951]	valid_0's binary_logloss: 0.407641
# [3952]	valid_0's binary_logloss: 0.40764
# [3953]	valid_0's binary_logloss: 0.407641
# [3954]	valid_0's binary_logloss: 0.407639
# [3955]	valid_0's binary_logloss: 0.407638
# [3956]	valid_0's binary_logloss: 0.407637
# [3957]	valid_0's binary_logloss: 0.407641
# [3958]	valid_0's binary_logloss: 0.407642
# [3959]	valid_0's binary_logloss: 0.407641
# [3960]	valid_0's binary_logloss: 0.407641
# [3961]	valid_0's binary_logloss: 0.407641
# [3962]	valid_0's binary_logloss: 0.407639
# [3963]	valid_0's binary_logloss: 0.40764
# [3964]	valid_0's binary_logloss: 0.40764
# [3965]	valid_0's binary_logloss: 0.407642
# [3966]	valid_0's binary_logloss: 0.40764
# [3967]	valid_0's binary_logloss: 0.407642
# [3968]	valid_0's binary_logloss: 0.407642
# [3969]	valid_0's binary_logloss: 0.40764
# [3970]	valid_0's binary_logloss: 0.407639
# [3971]	valid_0's binary_logloss: 0.407641
# [3972]	valid_0's binary_logloss: 0.40764
# [3973]	valid_0's binary_logloss: 0.40764
# [3974]	valid_0's binary_logloss: 0.407639
# [3975]	valid_0's binary_logloss: 0.40764
# [3976]	valid_0's binary_logloss: 0.407639
# [3977]	valid_0's binary_logloss: 0.407639
# [3978]	valid_0's binary_logloss: 0.407639
# [3979]	valid_0's binary_logloss: 0.407641
# [3980]	valid_0's binary_logloss: 0.407639
# [3981]	valid_0's binary_logloss: 0.407638
# [3982]	valid_0's binary_logloss: 0.40764
# [3983]	valid_0's binary_logloss: 0.407638
# [3984]	valid_0's binary_logloss: 0.407637
# [3985]	valid_0's binary_logloss: 0.407638
# [3986]	valid_0's binary_logloss: 0.407638
# [3987]	valid_0's binary_logloss: 0.40764
# [3988]	valid_0's binary_logloss: 0.407639
# [3989]	valid_0's binary_logloss: 0.40764
# [3990]	valid_0's binary_logloss: 0.407639
# [3991]	valid_0's binary_logloss: 0.407642
# [3992]	valid_0's binary_logloss: 0.407644
# [3993]	valid_0's binary_logloss: 0.407645
# [3994]	valid_0's binary_logloss: 0.407644
# [3995]	valid_0's binary_logloss: 0.407643
# [3996]	valid_0's binary_logloss: 0.407645
# [3997]	valid_0's binary_logloss: 0.407646
# [3998]	valid_0's binary_logloss: 0.407647
# [3999]	valid_0's binary_logloss: 0.407648
# [4000]	valid_0's binary_logloss: 0.407648
# [4001]	valid_0's binary_logloss: 0.40765
# [4002]	valid_0's binary_logloss: 0.407652
# [4003]	valid_0's binary_logloss: 0.407652
# [4004]	valid_0's binary_logloss: 0.407652
# [4005]	valid_0's binary_logloss: 0.407653
# [4006]	valid_0's binary_logloss: 0.407654
# [4007]	valid_0's binary_logloss: 0.407655
# [4008]	valid_0's binary_logloss: 0.407655
# [4009]	valid_0's binary_logloss: 0.407656
# [4010]	valid_0's binary_logloss: 0.407654
# [4011]	valid_0's binary_logloss: 0.407653
# [4012]	valid_0's binary_logloss: 0.407652
# [4013]	valid_0's binary_logloss: 0.407654
# [4014]	valid_0's binary_logloss: 0.40765
# [4015]	valid_0's binary_logloss: 0.407649
# [4016]	valid_0's binary_logloss: 0.407649
# [4017]	valid_0's binary_logloss: 0.40765
# [4018]	valid_0's binary_logloss: 0.40765
# [4019]	valid_0's binary_logloss: 0.407651
# [4020]	valid_0's binary_logloss: 0.407648
# [4021]	valid_0's binary_logloss: 0.407649
# [4022]	valid_0's binary_logloss: 0.407648
# [4023]	valid_0's binary_logloss: 0.407649
# [4024]	valid_0's binary_logloss: 0.407649
# [4025]	valid_0's binary_logloss: 0.40765
# [4026]	valid_0's binary_logloss: 0.407649
# [4027]	valid_0's binary_logloss: 0.407647
# [4028]	valid_0's binary_logloss: 0.407647
# [4029]	valid_0's binary_logloss: 0.407646
# [4030]	valid_0's binary_logloss: 0.407648
# [4031]	valid_0's binary_logloss: 0.407648
# [4032]	valid_0's binary_logloss: 0.407649
# [4033]	valid_0's binary_logloss: 0.407649
# [4034]	valid_0's binary_logloss: 0.407649
# [4035]	valid_0's binary_logloss: 0.407649
# [4036]	valid_0's binary_logloss: 0.407654
# [4037]	valid_0's binary_logloss: 0.407653
# [4038]	valid_0's binary_logloss: 0.407651
# [4039]	valid_0's binary_logloss: 0.40765
# [4040]	valid_0's binary_logloss: 0.407652
# [4041]	valid_0's binary_logloss: 0.407649
# [4042]	valid_0's binary_logloss: 0.40765
# [4043]	valid_0's binary_logloss: 0.407646
# [4044]	valid_0's binary_logloss: 0.407646
# [4045]	valid_0's binary_logloss: 0.407643
# [4046]	valid_0's binary_logloss: 0.407643
# [4047]	valid_0's binary_logloss: 0.407643
# [4048]	valid_0's binary_logloss: 0.407644
# [4049]	valid_0's binary_logloss: 0.407645
# [4050]	valid_0's binary_logloss: 0.407647
# [4051]	valid_0's binary_logloss: 0.407646
# [4052]	valid_0's binary_logloss: 0.407648
# [4053]	valid_0's binary_logloss: 0.407649
# [4054]	valid_0's binary_logloss: 0.407648
# [4055]	valid_0's binary_logloss: 0.407649
# [4056]	valid_0's binary_logloss: 0.407648
# [4057]	valid_0's binary_logloss: 0.407649
# [4058]	valid_0's binary_logloss: 0.407649
# [4059]	valid_0's binary_logloss: 0.407651
# [4060]	valid_0's binary_logloss: 0.40765
# [4061]	valid_0's binary_logloss: 0.407648
# [4062]	valid_0's binary_logloss: 0.407649
# [4063]	valid_0's binary_logloss: 0.407649
# [4064]	valid_0's binary_logloss: 0.40765
# [4065]	valid_0's binary_logloss: 0.407651
# [4066]	valid_0's binary_logloss: 0.407651
# [4067]	valid_0's binary_logloss: 0.40765
# [4068]	valid_0's binary_logloss: 0.407652
# [4069]	valid_0's binary_logloss: 0.407652
# [4070]	valid_0's binary_logloss: 0.40765
# [4071]	valid_0's binary_logloss: 0.407645
# [4072]	valid_0's binary_logloss: 0.407644
# [4073]	valid_0's binary_logloss: 0.407641
# [4074]	valid_0's binary_logloss: 0.40764
# [4075]	valid_0's binary_logloss: 0.407641
# [4076]	valid_0's binary_logloss: 0.407642
# [4077]	valid_0's binary_logloss: 0.407642
# [4078]	valid_0's binary_logloss: 0.407644
# [4079]	valid_0's binary_logloss: 0.407643
# [4080]	valid_0's binary_logloss: 0.407646
# [4081]	valid_0's binary_logloss: 0.407643
# [4082]	valid_0's binary_logloss: 0.407642
# [4083]	valid_0's binary_logloss: 0.407643
# [4084]	valid_0's binary_logloss: 0.407643
# Early stopping, best iteration is:
# [3984]	valid_0's binary_logloss: 0.407637

# %%
# Visualize the first tree
lightgbm.plot_tree(model, tree_index=0, figsize=(20, 15), show_info=['split_gain', 'leaf_weight', 'leaf_count']);
plt.show();

# %% [markdown]
# # Model evaluation 1: Feature Importance

# %%
# Plot model evaluation metrics
plt.figure(figsize=(10, 6));

lightgbm.plot_metric(evaluation_result);
lightgbm.plot_importance(model, importance_type='gain', title='Feature Importance (Gain)', xlabel='Gain');
plt.show();

# %% [markdown]
# # Model evaluation 2: Prediction accuracy

# %%
# Make predictions on the test set
prediction = model.predict(feature_test, num_iteration=model.best_iteration);
binarized_prediction_result = [1 if pred > 0.5 else 0 for pred in prediction];

print(f"Best iteration: {model.best_iteration}")

# Evaluate the model
accuracy = accuracy_score(label_test, binarized_prediction_result);
print(f"Accuracy: {accuracy}");

# Calculate mean squared error
loss = log_loss(label_test, prediction);
print(f"Log Loss: {loss}");

auc_roc = roc_auc_score(label_test, binarized_prediction_result);
print(f"AUC-ROC: {auc_roc}");
# Out:
# Best iteration: 3984
# Accuracy: 0.8335021952043229
# Log Loss: 0.40763653007830175
# AUC-ROC: 0.6566278024635094
